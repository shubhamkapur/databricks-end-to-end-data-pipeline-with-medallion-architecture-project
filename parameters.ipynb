# %%
### define an array of dictionaries and use this array as an inpurt to a for loop (for each activity) 
datasets = [
    {"file_name": "orders"},
    {"file_name": "customers"},
    {"file_name": "products"}
]

# %%
### run this notebook in workflow and using this utility we can return datasets with name "output_datasets"
dbutils.jobs.taskValues.set("output_datasets", datasets)
